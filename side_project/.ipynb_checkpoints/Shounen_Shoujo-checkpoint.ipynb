# %%
import matplotlib as plt
# %matplotlib inline
import pandas as pdimport cv2
import numpy as np
import spacy
from PIL import Image 
from string import punctuation
import nltk
from nltk.corpus import stopwords
import os

# %%
import pytesseract 
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
pytesseract.pytesseract.tesseract_cmd = '/usr/local/Cellar/tesseract/4.1.1/bin/tesseract'
tessdata_dir_config = "/usr/local/Cellar/tesseract/4.1.1/bin/tesseract"

# %%
#reads 1st page of english test version of shounen1 folder
op_eng_img=Image.open("/Users/lsanchez/Desktop/DIGHUM101-2020-project/shounen1/onepiece_engtest.jpg")
op_eng_img.load()
eng_text = pytesseract.image_to_string(op_eng_img, lang = "eng")    


print(type(op_eng_img))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
#counts freq of words in image
from collections import Counter
for char in punctuation:
    txt = eng_text.lower().replace(char, "")
tokens = eng_text.split()
tokens

freq = Counter(tokens)
freq.most_common(10)
# Out:
# [('THE', 4),
#  ('TO', 3),
#  ('ee', 2),
#  ('IT...', 2),
#  ('SURPRISINGLY,', 1),
#  ('ata', 1),
#  ('yao', 1),
#  ('WORDS', 1),
#  ('HE', 1),
#  ('SPOKE', 1)]

# %%
import os
f = []
t = []
input_dir = r'C:/Users/lsanchez/Desktop/DIGHUM101-2020-project/shonen1/'

for root, dirs, filenames in os.walk(input_dir):
    for filename in filenames:
        try:
            print(filename)
            f.append(filename)
            img = Image.open(input_dir + filename)
            text = pytesseract.image_to_string(img, lang = 'eng')
            t.append(text)
            print(text)
            print('-='*20)
        except:
            continue

df = pd.DataFrame(list(zip(f, t)), columns=['file_Name','Text'])
print(df)
# Out:
# Empty DataFrame
# Columns: [file_Name, Text]
# Index: []

# %%
##reads english version of manga, but does not read boxes correctly
op_eng_img1=Image.open("/Users/lsanchez/Desktop/DIGHUM101-2020-project/shounen1/onepiece_engtest.jpg")
op_eng_img1.load()
eng_text = pytesseract.image_to_string(op_eng_img1, lang = "eng")

# %%
imgs = []
path = "/Users/lsanchez/Desktop/DIGHUM101-2020-project/shounen1/"

for imageName in os.listdir(path):
    inputPath = os.path.join(path, imageName) 
    img_open = cv2.imread(inputPath)
    img_open1 = imgs.append(str(img_open))
    print(imgs)


shonen_text = pytesseract.image_to_string(img_open)
print(shonen_text)

# %%
import cv2

# %%
#reads english version of manga, but does not read boxes correctly
shounen_dir =Image.open("/Users/lsanchez/Desktop/DIGHUM101-2020-project/shounen1/onepiece_engtest.jpg")
shounen_dir.load()
shounen_text = pytesseract.image_to_string(shounen_dir, lang = "eng")    
print(shounen_text)
# Out:
# SURPRISINGLY,
# ata yao
# WORDS HE
#
# SPOKE BEFORE
# THEY LOPPED
# OFF HIS HEAD
#
# INSPIRED
#
# AQVENTURERS
#
# THROUGHOUT
#
# THE WORLO TO
#
# SAIL THE SEAS.
#
# SS
# ABOUT TO
# WITNESS
# )
# GREAT ERA
#
# GOLD
#
# ROGER,
#
# THE
# WEALTH, "KING OF
#
# FAME aries
#
# ANO ee
# power PIRATES,
#
# HAD ALL
# ott =e)
# ee Tt (ill,
#
# HIS.
#
#
#
# iv
#
# MY
# TREASURE?
# WHY, IT’S RIGHT
# WHERE | LEFT IT...
#
# YOURS IF YOU
# CAN FINO IT...
# BUT YOU'LL HAVE
# TO SEARCH THE
# WHOLE WORLD!
#
#
#
# {My
#
# (y)

# %%
#openning and reading all images in folder
## remove .DS_Store files in bash: rm -v **/.DS_Store 

indir = r'/Users/lsanchez/Desktop/DIGHUM101-2020-project/shounen1/'
text_list = []
for root, dirs, filenames in os.walk(indir):
    for filename in filenames:
        im = Image.open(indir + filename)
        all_img_text = pytesseract.image_to_string(im, lang='eng').lower()
        text_list = text_list + all_img_text.split()

# %%
import string

def remove_punctuation(word_list):
    for i in range(len(word_list)):
        word = word_list[i]
        for letter in word:
             if (letter in string.punctuation):
                word = word.replace(letter, "")
        word_list[i] = word
    return word_list
      
text_list = remove_punctuation(text_list)

# %%
#text_list_str = str(text_list)
#print(text_list)
#no_stops = [word for word in tokens if word not in stopwords.words('english')]
#no_stops

#print(text_list.remove(""))
test_a = text_list.remove("")

print(test_a)

#freq_a = Counter(test_a)
#freq = Counter(text_list) 
#freq_a.most_common(10)
# Out:
# None

# %%
#Can disregard this cell
##gives array from images in shounen1


import matplotlib.image as mpimg

def load_images(folder):
    images = []
    for filename in os.listdir(folder):
        img = mpimg.imread(os.path.join(folder, filename))
        if img is not None:
            images.append(img)
    return images
img_array = load_images("/Users/lsanchez/Desktop/DIGHUM101-2020-project/shounen1/")
read_array = pytesseract.image_to_string()
# Out:
# [array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
# ...

# %%
# Out:
# /Users/lsanchez/Desktop/DIGHUM101-2020-Project/shonen1/onepiece_pg2.jpg
